# %% [markdown]
# # Installing Dependencies

# %%
# !apt-get -qq -y install libnvtoolsext1 > /dev/null
# !ln -snf /usr/lib/x86_64-linux-gnu/libnvrtc-builtins.so.8.0 /usr/lib/x86_64-linux-gnu/libnvrtc-builtins.so
# !apt-get -qq -y install xvfb freeglut3-dev ffmpeg> /dev/null
# !pip -q install gym
# !pip -q install pyglet 
# !pip -q install pyopengl
# !pip -q install pyvirtualdisplay
# !pip -q install stable-baselines3
# !pip -q install box2d-py
# !pip -q install gym[Box_2D]
# Out:
# WARNING: gym 0.17.3 does not provide the extra 'box_2d'

# %%
import gym
import numpy as np
import math
import matplotlib.pyplot as plt
from collections import deque
import random
from gym import wrappers

from pyvirtualdisplay import Display
display = Display(visible=0, size=(1024, 768))
display.start()
import os
# os.environ["DISPLAY"] = ":" + str(display.display) + "." + str(display.screen)

import matplotlib.animation
import numpy as np
from IPython.display import HTML

# Note, you may get a few warnings regarding Tensorflow and xdpyinfo, these are to be expected
import itertools

# %% [markdown]
# #OpenAI Gym
#
# Gym is a toolkit for developing and comparing reinforcement learning algorithms. It makes no assumptions about the structure of your agent, and is compatible with any numerical computation library, such as TensorFlow or PyTorch.
#
# In this notebook, we will have a quick introduction to OpenAI Gym and code-up one example environment named "MountainCar".
#
# **We strongly recommend looking over the ["Getting Started" documentation](https://gym.openai.com/docs/) before working on this worksheet.**

# %% [markdown]
# # Lunar Lander Environment
# We are trying to land a robot on the moon!
#
# From OpenAI Gym docs:
# Landing pad is always at coordinates (0,0). Coordinates are the first two numbers in state vector. Reward for moving from the top of the screen to landing pad and zero speed is about 100..140 points. If lander moves away from landing pad it loses reward back. Episode finishes if the lander crashes or comes to rest, receiving additional -100 or +100 points. Each leg ground contact is +10. Firing main engine is -0.3 points each frame. Solved is 200 points. Landing outside landing pad is possible. Fuel is infinite, so an agent can learn to fly and then land on its first attempt. Four discrete actions available: do nothing, fire left orientation engine, fire main engine, fire right orientation engine.
#
#
# >The observation space is 6 dimensional`:
# - X position
# - Y position
# - X velocity
# - Y velocity
# - θ angle
# - ω angular velocity
# - bool: left leg on gound
# - bool: right leg on ground
#
# >There are four possible actions of type `Discrete(4)`:
# - 0: Do nothing
# - 1: Fire left engine
# - 2: Fire main engine
# - 3: Fire right engine

# %% [markdown]
# Let's now create the environment from gym.

# %%
# Initialize the environment
np.random.seed(0)
env = gym.make('LunarLander-v2')
print(env.observation_space) # This is the state representation
print(env.action_space) # These are the available actions
# Out:
# Box(-inf, inf, (8,), float32)
# Discrete(4)

# %% [markdown]
# In order to interact with the environment, we're going to use the following line of code in a loop to represent one environment step
#
# ```observation, reward, done, info = env.step(action)```
#
# Here, we pass in an action to the environment and it will update some internal variables and produce the new state (observation), the reward collected at that timestep, whether the simulation has been completed, and then some extra environment specific info.
#
# We can use this call in a for loop to simulate a complete episode or rollout.

# %%
# Helper functions
def play_once(env, render=False, verbose=False):
    '''
    Run the simulation for 1 episode
    '''
    frames = []
    observation = env.reset()
    episode_reward = 0.
    for step in itertools.count():
        if render:
            frames.append(env.render(mode = 'rgb_array'))
        action = get_action(observation)
        observation, reward, done, _ = env.step(action)
        episode_reward += reward
        if done:
            break
    if verbose:
        print('got {} rewards in {} steps'.format(
                episode_reward, step + 1))
    return episode_reward, frames

# %% [markdown]
# ## The Simulation
# Our task is to develop a policy -- a mapping from the robot's current state to an action (`do nothing`, `thrust left`, `thrust up`, `thrust right`) that is evaluated at each timestep. The `play_once` function above will call a function `get_action` to get the action that we want to apply to the car given its current state.
#
# Let's start with a dumb policy, simply picking a random action amongst the available options.

# %%
def get_action(observation):
    # TODO: Pick a random action
    action = env.action_space.sample()
    return action

# %%
# run the simulation
episode_rewards, frames = play_once(env, render=True, verbose=True)
# Out:
# got -225.02165654548537 rewards in 74 steps

# %% [markdown]
# In order to see what happened, we can use the following code to generate a video from the frames of the rollout.

# %%
# render the frames
plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi = 72)
patch = plt.imshow(frames[0])
plt.axis('off')
animate = lambda i: patch.set_data(frames[i])
ani = matplotlib.animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval = 50)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img53d00b11b1b848139b715d7472b3b53f">
#   <div class="anim-controls">
#     <input id="_anim_slider53d00b11b1b848139b715d7472b3b53f" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim53d00b11b1b848139b715d7472b3b53f.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim53d00b11b1b848139b715d7472b3b53f.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim53d00b11b1b848139b715d7472b3b53f.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim53d00b11b1b848139b715d7472b3b53f.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim53d00b11b1b848139b715d7472b3b53f.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim53d00b11b1b848139b715d7472b3b53f.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim53d00b11b1b848139b715d7472b3b53f.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim53d00b11b1b848139b715d7472b3b53f.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim53d00b11b1b848139b715d7472b3b53f.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim53d00b11b1b848139b715d7472b3b53f.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select53d00b11b1b848139b715d7472b3b53f" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_53d00b11b1b848139b715d7472b3b53f"
#              >
#       <label for="_anim_radio1_53d00b11b1b848139b715d7472b3b53f">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_53d00b11b1b848139b715d7472b3b53f"
#              checked>
#       <label for="_anim_radio2_53d00b11b1b848139b715d7472b3b53f">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_53d00b11b1b848139b715d7472b3b53f"
#              >
#       <label for="_anim_radio3_53d00b11b1b848139b715d7472b3b53f">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img53d00b11b1b848139b715d7472b3b53f";
#     var slider_id = "_anim_slider53d00b11b1b848139b715d7472b3b53f";
#     var loop_select_id = "_anim_loop_select53d00b11b1b848139b715d7472b3b53f";
#     var frames = new Array(74);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+WH4yJAAAU/0lEQVR4nO3de4yVhZ3w8d+ZMwzMheE2DoiKKFdx\
# nCI3aaHE7lt0W4m1ttXaNP3nNdtIq+3WRhMvNalLK2qqpmmN2bqp1rRpNIW8DfUW0rC0rlJrXWEX\
# AZctfeUiKkVuwzDMnPePeWGWAjrqb+bMDJ9PQsJzOef8chhyvnmeZ55TKJVKpQAAIE1FuQcAABho\
# BBYAQDKBBQCQTGABACQTWAAAyQQWAEAygQUAkExgAQAkE1gAAMkEFgBAMoEFAJBMYAEAJBNYAADJ\
# BBYAQDKBBQCQTGABACQTWAAAyQQWAEAygQUAkExgAQAkE1gAAMkEFgBAMoEFAJBMYAEAJBNYAADJ\
# BBYAQDKBBQCQTGABACQTWAAAyQQWAEAygQUAkExgAQAkE1gAAMkEFgBAMoEFAJBMYAEAJBNYAADJ\
# BBYAQDKBBQCQTGABACQTWAAAyQ

# %% [markdown]
# # Reinforcement Learning Policy
#
# Ultimately, we want to create a much better policy than a random action from the observation. Clearly, we can see that given the 8 observation variables, picking an action is hard. In order to be able to solve this task, we will use a powerful algorithm, `A2C (Asynchronous Actor-Critic)`, from a large collection of actively maintained RL algorithms, `stable baselines`.

# %% [markdown]
# Let's start by creating the model and then training it for a number of epochs.

# %%
from stable_baselines3 import A2C

# TODO: Create RL Model and train
model  = A2C("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=25000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 113      |
# |    ep_rew_mean        | -276     |
# | time/                 |          |
# |    fps                | 472      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.18    |
# |    explained_variance | 0.0272   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -13.5    |
# |    value_loss         | 65.3     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 108       |
# |    ep_rew_mean        | -333      |
# | time/                 |           |
# |    fps                | 516       |
# |    iterations         | 200       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -0.646    |
# |    explained_variance | -0.000248 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -11.3     |
# |    value_loss         | 124       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 121      |
# |    ep_rew_mean        | -404     |
# | time/                 |          |
# |    fps                | 525      |
# |    iterations         | 300      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | -0.00214 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -6.82    |
# |    value_loss         | 48.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 116      |
# |    ep_rew_mean        | -423     |
# | time/                 |          |
# |    fps                | 541      |
# |    iterations         | 400      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.01    |
# |    explained_variance | 0.00298  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -4.16    |
# |    value_loss         | 98.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 118      |
# |    ep_rew_mean        | -451     |
# | time/                 |          |
# |    fps                | 547      |
# |    iterations         | 500      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -1       |
# |    explained_variance | -0.00378 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 1.65     |
# |    value_loss         | 4.34     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 119      |
# |    ep_rew_mean        | -476     |
# | time/                 |          |
# |    fps                | 551      |
# |    iterations         | 600      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | 0.0162   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -5.65    |
# |    value_loss         | 22.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 122      |
# |    ep_rew_mean        | -449     |
# | time/                 |          |
# |    fps                | 553      |
# |    iterations         | 700      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -1.12    |
# |    explained_variance | -0.00209 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -2.29    |
# |    value_loss         | 2.57     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 127      |
# |    ep_rew_mean        | -443     |
# | time/                 |          |
# |    fps                | 552      |
# |    iterations         | 800      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.01    |
# |    explained_variance | -0.00148 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -9.87    |
# |    value_loss         | 149      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 136      |
# |    ep_rew_mean        | -436     |
# | time/                 |          |
# |    fps                | 548      |
# |    iterations         | 900      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.697   |
# |    explained_variance | -0.0307  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -40.6    |
# |    value_loss         | 999      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 141      |
# |    ep_rew_mean        | -431     |
# | time/                 |          |
# |    fps                | 547      |
# |    iterations         | 1000     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | 0.00143  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -2.57    |
# |    value_loss         | 9.18     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 148      |
# |    ep_rew_mean        | -423     |
# | time/                 |          |
# |    fps                | 541      |
# |    iterations         | 1100     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.768   |
# |    explained_variance | -0.012   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 4.06     |
# |    value_loss         | 40.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 151      |
# |    ep_rew_mean        | -406     |
# | time/                 |          |
# |    fps                | 539      |
# |    iterations         | 1200     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.619   |
# |    explained_variance | -0.0264  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -1.17    |
# |    value_loss         | 21.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 159      |
# |    ep_rew_mean        | -394     |
# | time/                 |          |
# |    fps                | 536      |
# |    iterations         | 1300     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.818   |
# |    explained_variance | 0.000498 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 3.19     |
# |    value_loss         | 57.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 163      |
# |    ep_rew_mean        | -391     |
# | time/                 |          |
# |    fps                | 529      |
# |    iterations         | 1400     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.679   |
# |    explained_variance | -0.0394  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 5.42     |
# |    value_loss         | 71.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 176      |
# |    ep_rew_mean        | -379     |
# | time/                 |          |
# |    fps                | 513      |
# |    iterations         | 1500     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.72    |
# |    explained_variance | 0.00876  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -1.94    |
# |    value_loss         | 3.24     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 179      |
# |    ep_rew_mean        | -364     |
# | time/                 |          |
# |    fps                | 511      |
# |    iterations         | 1600     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.741   |
# |    explained_variance | 0.00422  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -1.8     |
# |    value_loss         | 25.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 183      |
# |    ep_rew_mean        | -360     |
# | time/                 |          |
# |    fps                | 508      |
# |    iterations         | 1700     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.912   |
# |    explained_variance | 0.00288  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 1.38     |
# |    value_loss         | 9.09     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 186      |
# |    ep_rew_mean        | -357     |
# | time/                 |          |
# |    fps                | 505      |
# |    iterations         | 1800     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.599   |
# |    explained_variance | -0.0236  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 9.12     |
# |    value_loss         | 209      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 192      |
# |    ep_rew_mean        | -352     |
# | time/                 |          |
# |    fps                | 503      |
# |    iterations         | 1900     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.182   |
# |    explained_variance | 0.015    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.0651  |
# |    value_loss         | 6.12     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 192      |
# |    ep_rew_mean        | -344     |
# | time/                 |          |
# |    fps                | 504      |
# |    iterations         | 2000     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | -0.00398 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.995    |
# |    value_loss         | 1.28     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 192      |
# |    ep_rew_mean        | -336     |
# | time/                 |          |
# |    fps                | 505      |
# |    iterations         | 2100     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -0.281   |
# |    explained_variance | -0.133   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 0.438    |
# |    value_loss         | 46.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 194      |
# |    ep_rew_mean        | -329     |
# | time/                 |          |
# |    fps                | 506      |
# |    iterations         | 2200     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -0.679   |
# |    explained_variance | -0.0146  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 2.27     |
# |    value_loss         | 40.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 196      |
# |    ep_rew_mean        | -323     |
# | time/                 |          |
# |    fps                | 507      |
# |    iterations         | 2300     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -0.629   |
# |    explained_variance | -0.0301  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 5.51     |
# |    value_loss         | 152      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 197      |
# |    ep_rew_mean        | -319     |
# | time/                 |          |
# |    fps                | 508      |
# |    iterations         | 2400     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.682   |
# |    explained_variance | -0.00798 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 3.4      |
# |    value_loss         | 55.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 197      |
# |    ep_rew_mean        | -319     |
# | time/                 |          |
# |    fps                | 499      |
# |    iterations         | 2500     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.568   |
# |    explained_variance | -0.107   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.342   |
# |    value_loss         | 0.301    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 206      |
# |    ep_rew_mean        | -306     |
# | time/                 |          |
# |    fps                | 498      |
# |    iterations         | 2600     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.593   |
# |    explained_variance | 0.0722   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 4.89     |
# |    value_loss         | 67.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 207      |
# |    ep_rew_mean        | -298     |
# | time/                 |          |
# |    fps                | 498      |
# |    iterations         | 2700     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -0.691   |
# |    explained_variance | -0.133   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 5.6      |
# |    value_loss         | 109      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 208      |
# |    ep_rew_mean        | -295     |
# | time/                 |          |
# |    fps                | 496      |
# |    iterations         | 2800     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.563   |
# |    explained_variance | -1.28    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 1.49     |
# |    value_loss         | 35.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 209      |
# |    ep_rew_mean        | -286     |
# | time/                 |          |
# |    fps                | 497      |
# |    iterations         | 2900     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.325   |
# |    explained_variance | 0.0414   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | -2.47    |
# |    value_loss         | 2.98     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 207      |
# |    ep_rew_mean        | -278     |
# | time/                 |          |
# |    fps                | 498      |
# |    iterations         | 3000     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.641   |
# |    explained_variance | -0.0725  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 5.79     |
# |    value_loss         | 188      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 206      |
# |    ep_rew_mean        | -274     |
# | time/                 |          |
# |    fps                | 499      |
# |    iterations         | 3100     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.563   |
# |    explained_variance | 0.193    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 6.02     |
# |    value_loss         | 161      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 207      |
# |    ep_rew_mean        | -271     |
# | time/                 |          |
# |    fps                | 498      |
# |    iterations         | 3200     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.668   |
# |    explained_variance | -5.95    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 1.59     |
# |    value_loss         | 10.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 208      |
# |    ep_rew_mean        | -264     |
# | time/                 |          |
# |    fps                | 498      |
# |    iterations         | 3300     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.868   |
# |    explained_variance | -1.46    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 1.02     |
# |    value_loss         | 0.856    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 208      |
# |    ep_rew_mean        | -264     |
# | time/                 |          |
# |    fps                | 494      |
# |    iterations         | 3400     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.487   |
# |    explained_variance | 0.177    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | -0.106   |
# |    value_loss         | 0.036    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 216      |
# |    ep_rew_mean        | -255     |
# | time/                 |          |
# |    fps                | 488      |
# |    iterations         | 3500     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.538   |
# |    explained_variance | 0.382    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | -0.341   |
# |    value_loss         | 0.544    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 215      |
# |    ep_rew_mean        | -251     |
# | time/                 |          |
# |    fps                | 488      |
# |    iterations         | 3600     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.416   |
# |    explained_variance | 0.328    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | -0.936   |
# |    value_loss         | 62.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 216      |
# |    ep_rew_mean        | -245     |
# | time/                 |          |
# |    fps                | 487      |
# |    iterations         | 3700     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.732   |
# |    explained_variance | -0.389   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -0.752   |
# |    value_loss         | 2.99     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 218      |
# |    ep_rew_mean        | -243     |
# | time/                 |          |
# |    fps                | 486      |
# |    iterations         | 3800     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.658   |
# |    explained_variance | 0.484    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -1       |
# |    value_loss         | 4.54     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 218      |
# |    ep_rew_mean        | -240     |
# | time/                 |          |
# |    fps                | 487      |
# |    iterations         | 3900     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -0.549   |
# |    explained_variance | 0.122    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | -4.36    |
# |    value_loss         | 109      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 219      |
# |    ep_rew_mean        | -237     |
# | time/                 |          |
# |    fps                | 486      |
# |    iterations         | 4000     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.96    |
# |    explained_variance | -0.602   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 3.08     |
# |    value_loss         | 14       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 220      |
# |    ep_rew_mean        | -235     |
# | time/                 |          |
# |    fps                | 486      |
# |    iterations         | 4100     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -0.65    |
# |    explained_variance | 0.193    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | -1.94    |
# |    value_loss         | 6.91     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 220      |
# |    ep_rew_mean        | -230     |
# | time/                 |          |
# |    fps                | 487      |
# |    iterations         | 4200     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -0.0254  |
# |    explained_variance | -0.176   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.00387 |
# |    value_loss         | 2.2      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 219      |
# |    ep_rew_mean        | -225     |
# | time/                 |          |
# |    fps                | 488      |
# |    iterations         | 4300     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -0.599   |
# |    explained_variance | 0.13     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 5.05     |
# |    value_loss         | 76.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 218      |
# |    ep_rew_mean        | -224     |
# | time/                 |          |
# |    fps                | 489      |
# |    iterations         | 4400     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.00911 |
# |    explained_variance | 0.43     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 0.000576 |
# |    value_loss         | 1.35     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 220      |
# |    ep_rew_mean        | -219     |
# | time/                 |          |
# |    fps                | 490      |
# |    iterations         | 4500     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -0.759   |
# |    explained_variance | -0.731   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | -2.63    |
# |    value_loss         | 17.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 224      |
# |    ep_rew_mean        | -212     |
# | time/                 |          |
# |    fps                | 490      |
# |    iterations         | 4600     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -0.581   |
# |    explained_variance | -0.156   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | 5.63     |
# |    value_loss         | 89.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 226      |
# |    ep_rew_mean        | -204     |
# | time/                 |          |
# |    fps                | 491      |
# |    iterations         | 4700     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -0.563   |
# |    explained_variance | 0.764    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 0.594    |
# |    value_loss         | 0.98     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 227      |
# |    ep_rew_mean        | -194     |
# | time/                 |          |
# |    fps                | 492      |
# |    iterations         | 4800     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -0.00917 |
# |    explained_variance | -0.385   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | -0.0233  |
# |    value_loss         | 586      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 228      |
# |    ep_rew_mean        | -178     |
# | time/                 |          |
# |    fps                | 493      |
# |    iterations         | 4900     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -0.128   |
# |    explained_variance | 0.902    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | -0.0213  |
# |    value_loss         | 0.921    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 231      |
# |    ep_rew_mean        | -165     |
# | time/                 |          |
# |    fps                | 493      |
# |    iterations         | 5000     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -0.773   |
# |    explained_variance | 0.881    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | -0.0667  |
# |    value_loss         | 1.79     |
# ------------------------------------

# %% [markdown]
# That was quite simple! We simply need to invoke the model and then train the model using 2 lines of code. Naturally, there's a number of hyperparameters as well as other algorithms available, so if you want to learn more or experiment the documentation is available [here](https://stable-baselines3.readthedocs.io/en/master/modules/a2c.html)

# %% [markdown]
# Now let's see how our model does:

# %%
def play_once(env, render=False, verbose=False):
    '''
    Run the simulation for 1 episode
    '''
    frames = []
    observation = env.reset()
    episode_reward = 0.
    for step in itertools.count():
        if render:
            frames.append(env.render(mode = 'rgb_array'))
        
        # TODO: use our trained model to produce an action from the observation
        action, _states = model.predict(observation)
        observation, reward, done, _ = env.step(action)
        episode_reward += reward
        if done:
            break
    if verbose:
        print('got {} rewards in {} steps'.format(
                episode_reward, step + 1))
    return episode_reward, frames

# run the simulation
episode_rewards, frames = play_once(env, render=True, verbose=True)
# Out:
# got -38.5953068856681 rewards in 167 steps

# %%
# render the frames
plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi = 72)
patch = plt.imshow(frames[0])
plt.axis('off')
animate = lambda i: patch.set_data(frames[i])
ani = matplotlib.animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval = 50)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imge34b32c8243441baaa9546495916d642">
#   <div class="anim-controls">
#     <input id="_anim_slidere34b32c8243441baaa9546495916d642" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anime34b32c8243441baaa9546495916d642.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anime34b32c8243441baaa9546495916d642.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anime34b32c8243441baaa9546495916d642.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anime34b32c8243441baaa9546495916d642.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anime34b32c8243441baaa9546495916d642.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anime34b32c8243441baaa9546495916d642.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anime34b32c8243441baaa9546495916d642.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anime34b32c8243441baaa9546495916d642.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anime34b32c8243441baaa9546495916d642.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anime34b32c8243441baaa9546495916d642.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selecte34b32c8243441baaa9546495916d642" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_e34b32c8243441baaa9546495916d642"
#              >
#       <label for="_anim_radio1_e34b32c8243441baaa9546495916d642">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_e34b32c8243441baaa9546495916d642"
#              checked>
#       <label for="_anim_radio2_e34b32c8243441baaa9546495916d642">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_e34b32c8243441baaa9546495916d642"
#              >
#       <label for="_anim_radio3_e34b32c8243441baaa9546495916d642">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imge34b32c8243441baaa9546495916d642";
#     var slider_id = "_anim_slidere34b32c8243441baaa9546495916d642";
#     var loop_select_id = "_anim_loop_selecte34b32c8243441baaa9546495916d642";
#     var frames = new Array(167);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+WH4yJAAAWkUlEQVR4nO3de4xVhb3o8d+ePcwD5KHDU4m8HFQq\
# dSxcReqxyjXRVtQSU5W0em3jo2mjFtL4SjWtsU0bbY7RtpHKsXJaSkpN9aSWVNNWQwXERzo+Urwo\
# 4gNU8MgbZsCBff+YI3Op1oL8ZtbM+PkkJKy9N3v/soe993fWWnutUqVSqQQAAGmqih4AAKC3EVgA\
# AMkEFgBAMoEFAJBMYAEAJBNYAADJBBYAQDKBBQCQTGABACQTWAAAyQQWAEAygQUAkExgAQAkE1gA\
# AMkEFgBAMoEFAJBMYAEAJBNYAADJBBYAQDKBBQCQTGABACQTWAAAyQQWAEAygQUAkExgAQAkE1gA\
# AMkEFgBAMoEFAJBMYAEAJBNYAADJBBYAQDKBBQCQTGABACQTWAAAyQQWAEAygQUAkExgAQAkE1gA\
# AMkEFgBAMoEFAJBMYAEAJBNYA
